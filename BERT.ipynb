# %%
2017  --> Transformer

2018 --> ULMFit  --> Transfer Learning

# %%
# Language Model : Estimating the probability of a token occuring in a sequence

# %%
# Language Model (Language Model) :

-- Model learn about langugae

# %%
# AGI (Artificial General Intelligence)

# %%
## OpenAI - in 2018
GPT (Generative pretrained transformer)

# %%
GPT : Trained on Decoder --> It only understand in one direction
                             (because of Masked multi-head attention)

# %%
apple is great company

# %%
# 2018 : Google
BERT : Biredirectional Encoder representation from transformer

# %% [markdown]
# ####BERT : Biredirectional Encoder representation from transformer

# %%
## Masked Language Model (MLM) :  fill in the blank
we are [MASK] transformer

Input --> Encoder --> V1, V2, V3, V4

V3 (mask) --> Learning

# %%
## Task used for training BERT Model :
1. Masked Language Model (MLM)
2. Next Sentence Prediction (NSP)

# %%
Bidirectional encoder representations from transformers (BERT) is a language model
introduced in October 2018 by researchers at Google.
It learns to represent text as a sequence of vectors using self-supervised learning.
It uses the encoder-only transformer architecture.
BERT dramatically improved the state of the art for large language models.
As of 2020, BERT is a ubiquitous baseline in natural language processing (NLP) experiments.[3]

# %%
#  Next Sentence Prediction (NSP)
(BERT) is a language model introduced in October 2018 by researchers at Google.
It learns to represent text as a sequence of vectors using self-supervised learning.

(BERT) is a language model introduced in October 2018 by researchers at Google.
this is genai class


[CLS] First Sentence [SEP] Second Sentence [SEP]

Input Ids --> Input Embedding --> Positional Encoding --> Segment Embedding [0, 1]
Encoder --> Context vector

## Binary Classification : isNextsentence, NotNextSentence

Context Vector of [CLS]  --> output layer --> Binary Classification (NSP)

# %%
[CLS]  --> Classification
[SEP]  --> Separator
